# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

# %%
trainingSet = pd.read_csv('data/training.csv')  # read the data
testingSet = pd.read_csv('data/testing.csv')  # read the data

# %%
# print(trainingSet.head(10))  # displays the first 5 elements in training data
# print(testingSet.head(10))  # displays the first 5 elements in testing data

# %%
# training data
X_train = trainingSet.iloc[:, :-1]  # X_train contains the features only without the class
y_train = trainingSet.iloc[:, -1]  # Y_train contains the class only without the features

# %%
# testing data
X_test = testingSet.iloc[:, :-1]  # X_test contains the features only without the class
y_test = testingSet.iloc[:, -1]  # Y_test contains the class only without the features

# %%
# print(trainingSet.head(5))  # displays the first 5 elements in training data
# print(X_train.head(5))  # displays the features of first 5 elements in training data
# print(y_train.head(5))  # displays the class of first 5 elements in training data

# %%
# print(testingSet.head(5))  # displays the first 5 elements in testing data
# print(X_test.head(5))  # displays the features of first 5 elements in testing data
# print(y_test.head(5))  # displays the class of first 5 elements in testing data

# %%
# print(len(X_train))
# print(len(X_test))
# print(len(y_train))
# print(len(y_test))

# %%
scaler = MinMaxScaler(copy=True, feature_range=(0,1))
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Cross validation range(1,1000) with step 100

# %%
n_scores = []
stratifiedKF = StratifiedKFold(n_splits=10)
for n in range(1,1000,100):
    rnForest = RandomForestClassifier(n_estimators=n)
    score = cross_val_score(rnForest, X_train, y_train, cv=stratifiedKF, scoring='accuracy')
    n_scores.append(score.mean())
    print("N = " + str(n) + " and mean score from 10 folds is " + str(score.mean()))
# Out:
# N = 1 and mean score from 10 folds is 0.7746702514845525
# N = 101 and mean score from 10 folds is 0.8587163296208121
# N = 201 and mean score from 10 folds is 0.8582879530051356
# N = 301 and mean score from 10 folds is 0.8577547911592734
# N = 401 and mean score from 10 folds is 0.858715303432486
# N = 501 and mean score from 10 folds is 0.8588222550602488
# N = 601 and mean score from 10 folds is 0.8597835654799368
# N = 701 and mean score from 10 folds is 0.8596767278730993
# N = 801 and mean score from 10 folds is 0.8592489213620483
# N = 901 and mean score from 10 folds is 0.858288409088836

# %%
plt.figure(figsize=(12,8))
plt.plot(range(1,1000,100), n_scores, color='red', linestyle='dashed', marker='o',
        markerfacecolor='blue', markersize=10)
plt.title('Accuracy Rate for N-Estimators Value')
plt.xlabel('N-Estimators Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ## Cross validation range(1,300) with step 20

# %%
n_scores = []
stratifiedKF = StratifiedKFold(n_splits=10)
for n in range(1,300,20):
    rnForest = RandomForestClassifier(n_estimators=n)
    score = cross_val_score(rnForest, X_train, y_train, cv=stratifiedKF, scoring='accuracy')
    n_scores.append(score.mean())
    print("N = " + str(n) + " and mean score from 10 folds is " + str(score.mean()))
# Out:
# N = 1 and mean score from 10 folds is 0.776379539173029
# N = 21 and mean score from 10 folds is 0.8511316576818178
# N = 41 and mean score from 10 folds is 0.8536956462249952
# N = 61 and mean score from 10 folds is 0.85722003302046
# N = 81 and mean score from 10 folds is 0.8571131954136224
# N = 101 and mean score from 10 folds is 0.8578611726824107
# N = 121 and mean score from 10 folds is 0.8578612867033357
# N = 141 and mean score from 10 folds is 0.8572198049786095
# N = 161 and mean score from 10 folds is 0.8590362723366993
# N = 181 and mean score from 10 folds is 0.8595694341825613
# N = 201 and mean score from 10 folds is 0.858715303432486
# N = 221 and mean score from 10 folds is 0.8585011721351101
# N = 241 and mean score from 10 folds is 0.8580754180007115
# N = 261 and mean score from 10 folds is 0.8605312006859499
# N = 281 and mean score from 10 folds is 0.8596767278730993

# %%
plt.figure(figsize=(12,8))
plt.plot(range(1,300,20), n_scores, color='red', linestyle='dashed', marker='o',
        markerfacecolor='blue', markersize=10)
plt.title('Accuracy Rate for N-Estimators Value')
plt.xlabel('N-Estimators Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
maxAcc = max(n_scores)
max_index = n_scores.index(maxAcc)
n_est = 1 + 20*max_index
print(n_est, n_scores[max_index])
# Out:
# 261 0.8605312006859499

# %% [markdown]
# ## Build the model using the tuned parameter

# %%
rnForest = RandomForestClassifier(n_estimators=n_est)
rnForest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=261)

# %%
y_pred = rnForest.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      2006
#            1       0.85      0.88      0.86      2006
#
#     accuracy                           0.86      4012
#    macro avg       0.86      0.86      0.86      4012
# weighted avg       0.86      0.86      0.86      4012

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
labels = ['h','g']
columns = [f'Predicted {label}' for label in labels]
index = [f'Actual {label}' for label in labels]
table = pd.DataFrame(cm, columns=columns, index=index)
table
# Out:
#           Predicted h  Predicted g
# Actual h         1688          318
# Actual g          241         1765

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
specificity = cm[0,0]/(cm[0,0] + cm[0,1])
f1 = f1_score(y_test, y_pred)

print('model_accuracy = ', acc)
print('model_precision = ', prec)
print('model_recall = ', recall)
print('model_specificity = ', specificity)
print('model_f1 = ', f1)
# Out:
# model_accuracy =  0.8606679960119641
# model_precision =  0.8473355736917907
# model_recall =  0.8798604187437687
# model_specificity =  0.8414755732801595
# model_f1 =  0.8632917583761311
